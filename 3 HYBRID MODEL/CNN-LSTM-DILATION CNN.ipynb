# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import savgol_filter
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, roc_curve, auc

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.backend import clear_session

# %%
dataset_path = "/content/drive/My Drive/mhealth+dataset (1)/MHEALTHDATASET"

columns = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg_chest_1', 'ecg_chest_2',
    'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
    'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
    'magnet_ankle_x', 'magnet_ankle_y', 'magnet_ankle_z',
    'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
    'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
    'magnet_arm_x', 'magnet_arm_y', 'magnet_arm_z',
    'activity'
]

activity_labels = {
    1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down',
    4: 'Walking', 5: 'Climbing stairs', 6: 'Waist bends forward',
    7: 'Frontal elevation of arms', 8: 'Knees bending (crouching)',
    9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
}

def load_mhealth_data(path):
    all_data = []
    for file in sorted(os.listdir(path)):
        if file.endswith('.log'):
            df = pd.read_csv(os.path.join(path, file), delim_whitespace=True, header=None)
            df.columns = columns
            all_data.append(df)
    return pd.concat(all_data, ignore_index=True)

df = load_mhealth_data(dataset_path)
scaler = StandardScaler()
df[columns[:-1]] = scaler.fit_transform(df[columns[:-1]])

# %%
def segment_data(data, window_size=80, step=40):
    X, y = [], []
    for start in range(0, len(data) - window_size, step):
        end = start + window_size
        segment = data.iloc[start:end]
        if len(segment['activity'].unique()) == 1:
            X.append(segment.drop('activity', axis=1).values)
            y.append(segment['activity'].iloc[0])
    return np.array(X), np.array(y)

X, y = segment_data(df)
y_encoded = to_categorical(y - 1)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
clear_session()
input_layer = Input(shape=(X.shape[1], X.shape[2]))

# CNN layer
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(input_layer)
x = Dropout(0.3)(x)

# LSTM layer
x = LSTM(64, return_sequences=True)(x)

# Dilation CNN block
d1 = Conv1D(64, kernel_size=3, padding='causal', dilation_rate=1, activation='relu')(x)
d2 = Conv1D(64, kernel_size=3, padding='causal', dilation_rate=2, activation='relu')(d1)
d3 = Conv1D(64, kernel_size=3, padding='causal', dilation_rate=4, activation='relu')(d2)

x = GlobalAveragePooling1D()(d3)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.3)(x)
output_layer = Dense(y_train.shape[1], activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 80, 23)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 80, 64)         │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 80, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 80, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 80, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 80, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 80, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           780 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,500 (310.55 KB)
#  Trainable params: 79,500 (310.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

start = time.time()
history = model.fit(X_train, y_train, epochs=20, batch_size=128,
                    validation_data=(X_test, y_test),
                    callbacks=callbacks, verbose=1)
end = time.time()
# Out:
# Epoch 1/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 53s 258ms/step - accuracy: 0.6877 - loss: 1.3030 - val_accuracy: 0.8033 - val_loss: 0.4590 - learning_rate: 0.0010
# Epoch 2/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 81s 254ms/step - accuracy: 0.7898 - loss: 0.5106 - val_accuracy: 0.8699 - val_loss: 0.2964 - learning_rate: 0.0010
# Epoch 3/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 79s 239ms/step - accuracy: 0.8373 - loss: 0.3574 - val_accuracy: 0.8798 - val_loss: 0.2688 - learning_rate: 0.0010
# Epoch 4/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 83s 245ms/step - accuracy: 0.8639 - loss: 0.3027 - val_accuracy: 0.8749 - val_loss: 0.2754 - learning_rate: 0.0010
# Epoch 5/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 84s 253ms/step - accuracy: 0.8735 - loss: 0.2784 - val_accuracy: 0.8841 - val_loss: 0.2531 - learning_rate: 0.0010
# Epoch 6/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 81s 251ms/step - accuracy: 0.8811 - loss: 0.2581 - val_accuracy: 0.8952 - val_loss: 0.2364 - learning_rate: 0.0010
# Epoch 7/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 83s 255ms/step - accuracy: 0.8846 - loss: 0.2545 - val_accuracy: 0.8968 - val_loss: 0.2269 - learning_rate: 0.0010
# Epoch 8/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 81s 252ms/step - accuracy: 0.8924 - loss: 0.2390 - val_accuracy: 0.9030 - val_loss: 0.2201 - learning_rate: 0.0010
# Epoch 9/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 45s 242ms/step - accuracy: 0.8997 - loss: 0.2299 - val_accuracy: 0.8972 - val_loss: 0.2288 - learning_rate: 0.0010
# Epoch 10/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 83s 251ms/step - accuracy: 0.9035 - loss: 0.2194 - val_accuracy: 0.8876 - val_loss: 0.2328 - learning_rate: 0.0010
# Epoch 11/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 46s 244ms/step - accuracy: 0.8990 - loss: 0.2284 - val_accuracy: 0.9054 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 12/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 82s 244ms/step - accuracy: 0.9040 - loss: 0.2192 - val_accuracy: 0.9105 - val_loss: 0.2097 - learning_rate: 0.0010
# Epoch 13/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 85s 262ms/step - accuracy: 0.9043 - loss: 0.2166 - val_accuracy: 0.9085 - val_loss: 0.2131 - learning_rate: 0.0010
# Epoch 14/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 79s 243ms/step - accuracy: 0.9098 - loss: 0.2109 - val_accuracy: 0.9040 - val_loss: 0.2195 - learning_rate: 0.0010
# Epoch 15/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - accuracy: 0.9189 - loss: 0.1958 - val_accuracy: 0.9174 - val_loss: 0.2023 - learning_rate: 0.0010
# Epoch 16/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 84s 254ms/step - accuracy: 0.9187 - loss: 0.1940 - val_accuracy: 0.9147 - val_loss: 0.2048 - learning_rate: 0.0010
# Epoch 17/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 45s 240ms/step - accuracy: 0.9127 - loss: 0.1974 - val_accuracy: 0.9152 - val_loss: 0.2064 - learning_rate: 0.0010
# Epoch 18/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 84s 252ms/step - accuracy: 0.9156 - loss: 0.1960 - val_accuracy: 0.9181 - val_loss: 0.2062 - learning_rate: 0.0010
# Epoch 19/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 46s 247ms/step - accuracy: 0.9257 - loss: 0.1798 - val_accuracy: 0.9186 - val_loss: 0.2076 - learning_rate: 5.0000e-04
# Epoch 20/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 83s 255ms/step - accuracy: 0.9256 - loss: 0.1752 - val_accuracy: 0.9239 - val_loss: 0.2016 - learning_rate: 5.0000e-04

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print("Classification Report:")
report = classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values(), output_dict=True)
print(classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values()))

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=activity_labels.values(),
            yticklabels=activity_labels.values())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

accuracy = np.mean(y_pred_labels == y_true_labels)
mse = mean_squared_error(y_true_labels, y_pred_labels)
sensitivity = np.mean([report[label]['recall'] for label in activity_labels.values()])

specificity_list = []
for i in range(len(activity_labels)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp_fn = cm.sum() - cm[:, i].sum()
    specificity_list.append(tn / fp_fn if fp_fn != 0 else 0)
specificity = np.mean(specificity_list)

print(f"✅ Accuracy     : {accuracy*100:.2f}%")
print(f"✅ Sensitivity  : {sensitivity:.4f}")
print(f"✅ Specificity  : {specificity:.4f}")
print(f"✅ MSE          : {mse:.4f}")
print(f"✅ Training Time: {end - start:.2f} sec")
# Out:
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# Classification Report:
#                            precision    recall  f1-score   support
#
#            Standing still       0.71      0.99      0.83       151
#      Sitting and relaxing       0.74      1.00      0.85       140
#                Lying down       0.76      1.00      0.86       150
#                   Walking       0.88      1.00      0.93       157
#           Climbing stairs       0.80      0.88      0.84       159
#       Waist bends forward       0.78      0.96      0.86       150
# Frontal elevation of arms       0.73      0.98      0.84       127
# Knees bending (crouching)       0.81      0.99      0.89       149
#                   Cycling       0.82      0.99      0.90       137
#                   Jogging       0.86      0.99      0.92       148
#                   Running       0.87      0.90      0.89       138
#         Jump front & back       0.99      0.91      0.95      4374
#
#                  accuracy                           0.92      5980
#                 macro avg       0.81      0.97      0.88      5980
#              weighted avg       0.94      0.92      0.93      5980
# ✅ Accuracy     : 92.39%
# ✅ Sensitivity  : 0.9657
# ✅ Specificity  : 0.9820
# ✅ MSE          : 4.0605
# ✅ Training Time: 1469.94 sec

# %%
train_acc = savgol_filter(history.history['accuracy'], 9, 3)
val_acc = savgol_filter(history.history['val_accuracy'], 9, 3)
train_loss = savgol_filter(history.history['loss'], 9, 3)
val_loss = savgol_filter(history.history['val_loss'], 9, 3)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Train Acc')
plt.plot(val_acc, label='Val Acc')
plt.title("Accuracy Over Epochs")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.title("Loss Over Epochs")
plt.legend()
plt.tight_layout()
plt.show()

# %%
fpr = dict(); tpr = dict(); roc_auc = dict()
n_classes = y_test.shape[1]
colors = plt.cm.get_cmap('tab10', n_classes).colors

plt.figure(figsize=(6, 5))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f"{activity_labels[i+1]} (AUC = {roc_auc[i]:.2f})",
             color=colors[i % len(colors)])

plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve per Activity Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right", fontsize='small')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
val_loss = history.history['val_loss'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"\n🎯 Train Accuracy: {train_acc*100:.2f}% | Loss: {train_loss:.4f}")
print(f"\n📊 Val Accuracy  : {val_acc*100:.2f}%   | Loss: {val_loss:.4f}")
print(f"\n✅ Test Accuracy : {test_acc*100:.2f}% | Loss: {test_loss:.4f}")
# Out:
# 🎯 Train Accuracy: 93.42% | Loss: 0.1554
#
# 📊 Val Accuracy  : 92.39%   | Loss: 0.2016
#
# ✅ Test Accuracy : 92.39% | Loss: 0.2016
