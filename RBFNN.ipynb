# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Imports
import os, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import savgol_filter
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, roc_curve, auc

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Layer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.backend import clear_session
import tensorflow.keras.backend as K
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/drive/My Drive/mhealth+dataset (1)/MHEALTHDATASET"

columns = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg_chest_1', 'ecg_chest_2',
    'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
    'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
    'magnet_ankle_x', 'magnet_ankle_y', 'magnet_ankle_z',
    'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
    'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
    'magnet_arm_x', 'magnet_arm_y', 'magnet_arm_z',
    'activity'
]

activity_labels = {
    1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down',
    4: 'Walking', 5: 'Climbing stairs', 6: 'Waist bends forward',
    7: 'Frontal elevation of arms', 8: 'Knees bending (crouching)',
    9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
}

def load_mhealth_data(path):
    all_data = []
    for file in sorted(os.listdir(path)):
        if file.endswith('.log'):
            df = pd.read_csv(os.path.join(path, file), delim_whitespace=True, header=None)
            df.columns = columns
            all_data.append(df)
    return pd.concat(all_data, ignore_index=True)

df = load_mhealth_data(dataset_path)
scaler = StandardScaler()
df[columns[:-1]] = scaler.fit_transform(df[columns[:-1]])

# %%
def segment_data(data, window_size=80, step=40):
    X, y = [], []
    for start in range(0, len(data) - window_size, step):
        end = start + window_size
        segment = data.iloc[start:end]
        if len(segment['activity'].unique()) == 1:
            X.append(segment.drop('activity', axis=1).values)
            y.append(segment['activity'].iloc[0])
    return np.array(X), np.array(y)

X, y = segment_data(df)
y_encoded = to_categorical(y - 1)
X_flat = X.reshape((X.shape[0], -1))  # Flatten for RBFNN
X_train, X_test, y_train, y_test = train_test_split(X_flat, y_encoded, test_size=0.2, random_state=42)

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma=None, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = gamma if gamma is not None else 1.0

    def build(self, input_shape):
        self.centers = self.add_weight(name='centers',
                                       shape=(self.units, input_shape[-1]),
                                       initializer='uniform',
                                       trainable=True)
        self.betas = self.add_weight(name='betas',
                                     shape=(self.units,),
                                     initializer=tf.keras.initializers.Constant(self.gamma),
                                     trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        expanded_inputs = K.expand_dims(inputs, axis=1)
        expanded_centers = K.expand_dims(self.centers, axis=0)
        distances = K.sum(K.square(expanded_inputs - expanded_centers), axis=-1)
        return K.exp(-self.betas * distances)

# %%
clear_session()
inputs = Input(shape=(X_flat.shape[1],))
x = Dense(128, activation='relu')(inputs)
x = RBFLayer(64, gamma=0.5)(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(y_train.shape[1], activation='softmax')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

start = time.time()
history = model.fit(X_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(X_test, y_test),
                    callbacks=callbacks,
                    verbose=1)
end = time.time()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1840)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       235,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rbf_layer (RBFLayer)            │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │           780 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 248,844 (972.05 KB)
#  Trainable params: 248,844 (972.05 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.7103 - loss: 1.9667 - val_accuracy: 0.7314 - val_loss: 1.1490 - learning_rate: 0.0010
# Epoch 2/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.7291 - loss: 1.1210 - val_accuracy: 0.7314 - val_loss: 1.0735 - learning_rate: 0.0010
# Epoch 3/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7300 - loss: 1.0404 - val_accuracy: 0.7314 - val_loss: 0.9792 - learning_rate: 0.0010
# Epoch 4/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7296 - loss: 0.9528 - val_accuracy: 0.7314 - val_loss: 0.9327 - learning_rate: 0.0010
# Epoch 5/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7257 - loss: 0.9124 - val_accuracy: 0.7314 - val_loss: 0.8982 - learning_rate: 0.0010
# Epoch 6/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7281 - loss: 0.8729 - val_accuracy: 0.7314 - val_loss: 0.8795 - learning_rate: 0.0010
# Epoch 7/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7207 - loss: 0.8577 - val_accuracy: 0.7212 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 8/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7286 - loss: 0.8260 - val_accuracy: 0.7293 - val_loss: 0.8423 - learning_rate: 0.0010
# Epoch 9/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.7325 - loss: 0.8012 - val_accuracy: 0.7274 - val_loss: 0.8341 - learning_rate: 0.0010
# Epoch 10/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.7384 - loss: 0.7818 - val_accuracy: 0.7321 - val_loss: 0.8051 - learning_rate: 0.0010
# Epoch 11/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7473 - loss: 0.7603 - val_accuracy: 0.7351 - val_loss: 0.7911 - learning_rate: 0.0010
# Epoch 12/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7574 - loss: 0.7341 - val_accuracy: 0.7505 - val_loss: 0.7893 - learning_rate: 0.0010
# Epoch 13/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7674 - loss: 0.7055 - val_accuracy: 0.7518 - val_loss: 0.7765 - learning_rate: 0.0010
# Epoch 14/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7798 - loss: 0.6730 - val_accuracy: 0.7500 - val_loss: 0.7628 - learning_rate: 0.0010
# Epoch 15/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.7707 - loss: 0.6896 - val_accuracy: 0.7497 - val_loss: 0.7335 - learning_rate: 0.0010
# Epoch 16/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7871 - loss: 0.6482 - val_accuracy: 0.7465 - val_loss: 0.7197 - learning_rate: 0.0010
# Epoch 17/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7872 - loss: 0.6372 - val_accuracy: 0.7629 - val_loss: 0.7061 - learning_rate: 0.0010
# Epoch 18/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7886 - loss: 0.6414 - val_accuracy: 0.7475 - val_loss: 0.7799 - learning_rate: 0.0010
# Epoch 19/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7803 - loss: 0.6728 - val_accuracy: 0.7671 - val_loss: 0.7143 - learning_rate: 0.0010
# Epoch 20/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8002 - loss: 0.6180 - val_accuracy: 0.7726 - val_loss: 0.6987 - learning_rate: 0.0010

# %%
train_acc = savgol_filter(history.history['accuracy'], 9, 3)
val_acc = savgol_filter(history.history['val_accuracy'], 9, 3)
train_loss = savgol_filter(history.history['loss'], 9, 3)
val_loss = savgol_filter(history.history['val_loss'], 9, 3)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label="Train Acc (Smooth)")
plt.plot(val_acc, label="Val Acc (Smooth)")
plt.title("Accuracy Over Epochs")
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label="Train Loss (Smooth)")
plt.plot(val_loss, label="Val Loss (Smooth)")
plt.title("Loss Over Epochs")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=activity_labels.values(),
            yticklabels=activity_labels.values(),
            linewidths=0.5, linecolor='blue')
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix")
plt.tight_layout(); plt.show()

print("📊 Classification Report:")
report = classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values(), output_dict=True)
print(classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values()))

accuracy = np.mean(y_pred_labels == y_true_labels)
mse = mean_squared_error(y_true_labels, y_pred_labels)
sensitivity = np.mean([report[label]['recall'] for label in activity_labels.values()])

specificity_list = []
for i in range(len(activity_labels)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp_fn = cm.sum() - cm[:, i].sum()
    specificity_list.append(tn / fp_fn if fp_fn != 0 else 0)
specificity = np.mean(specificity_list)

print(f"\n✅ Final Evaluation:")
print(f"✔️ Accuracy     : {accuracy * 100:.2f}%")
print(f"✔️ Sensitivity  : {sensitivity:.4f}")
print(f"✔️ Specificity  : {specificity:.4f}")
print(f"✔️ MSE          : {mse:.4f}")
print(f"✔️ Training Time: {end - start:.2f} sec")
# Out:
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 📊 Classification Report:
#                            precision    recall  f1-score   support
#
#            Standing still       0.56      0.61      0.59       151
#      Sitting and relaxing       0.00      0.00      0.00       140
#                Lying down       0.00      0.00      0.00       150
#                   Walking       0.65      0.57      0.61       157
#           Climbing stairs       0.51      0.29      0.37       159
#       Waist bends forward       0.75      0.59      0.66       150
# Frontal elevation of arms       0.00      0.00      0.00       127
# Knees bending (crouching)       0.67      0.50      0.57       149
#                   Cycling       0.58      0.76      0.66       137
#                   Jogging       0.00      0.00      0.00       148
#                   Running       0.00      0.00      0.00       138
#         Jump front & back       0.80      0.94      0.86      4374
#
#                  accuracy                           0.77      5980
#                 macro avg       0.38      0.35      0.36      5980
#              weighted avg       0.68      0.77      0.72      5980
#
#
# ✅ Final Evaluation:
# ✔️ Accuracy     : 77.26%
# ✔️ Sensitivity  : 0.3543
# ✔️ Specificity  : 0.9586
# ✔️ MSE          : 10.7003
# ✔️ Training Time: 88.89 sec

# %%
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
val_loss = history.history['val_loss'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"\n🎯 Train Accuracy: {train_acc*100:.2f}% | Loss: {train_loss:.4f}")
print(f"\n📊 Val Accuracy: {val_acc*100:.2f}%   | Loss: {val_loss:.4f}")
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}% | Loss: {test_loss:.4f}")
# Out:
# 🎯 Train Accuracy: 80.79% | Loss: 0.6116
#
# 📊 Val Accuracy: 77.26%   | Loss: 0.6987
#
# ✅ Test Accuracy: 77.26% | Loss: 0.6987

# %%
fpr = dict(); tpr = dict(); roc_auc = dict()
n_classes = y_test.shape[1]
colors = plt.cm.get_cmap('tab10', n_classes).colors

plt.figure(figsize=(6, 5))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f"{activity_labels[i+1]} (AUC = {roc_auc[i]:.2f})",
             color=colors[i % len(colors)])

plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve per Activity Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right", fontsize='small')
plt.grid(True)
plt.tight_layout()
plt.show()
