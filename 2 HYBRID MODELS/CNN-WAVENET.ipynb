# %%
# ===================== MOUNT DRIVE =====================
from google.colab import drive
drive.mount('/content/drive')

# ===================== LIBRARIES =====================
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, roc_curve, auc

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, InputLayer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from scipy.signal import savgol_filter

# ===================== LOAD DATA =====================
dataset_path = "/content/drive/My Drive/mhealth+dataset (1)/MHEALTHDATASET"

columns = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg_chest_1', 'ecg_chest_2',
    'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
    'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
    'magnet_ankle_x', 'magnet_ankle_y', 'magnet_ankle_z',
    'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
    'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
    'magnet_arm_x', 'magnet_arm_y', 'magnet_arm_z',
    'activity'
]

activity_labels = {
    1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down',
    4: 'Walking', 5: 'Climbing stairs', 6: 'Waist bends forward',
    7: 'Frontal elevation of arms', 8: 'Knees bending (crouching)',
    9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
}

def load_mhealth_data(path):
    all_data = []
    for file in sorted(os.listdir(path)):
        if file.endswith('.log'):
            df = pd.read_csv(os.path.join(path, file), delim_whitespace=True, header=None)
            df.columns = columns
            all_data.append(df)
    return pd.concat(all_data, ignore_index=True)

df = load_mhealth_data(dataset_path)
scaler = StandardScaler()
df[columns[:-1]] = scaler.fit_transform(df[columns[:-1]])

# ===================== SEGMENTATION =====================
def segment_data(data, window_size=80, step=40):
    X, y = [], []
    for start in range(0, len(data) - window_size, step):
        end = start + window_size
        segment = data.iloc[start:end]
        if len(segment['activity'].unique()) == 1:
            X.append(segment.drop('activity', axis=1).values)
            y.append(segment['activity'].iloc[0])
    return np.array(X), np.array(y)

X, y = segment_data(df)
y_encoded = to_categorical(y - 1)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# ===================== CNN-WAVENET MODEL =====================
model = Sequential([
    InputLayer(input_shape=X.shape[1:]),

    Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Conv1D(filters=64, kernel_size=2, dilation_rate=1, padding='causal', activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Conv1D(filters=64, kernel_size=2, dilation_rate=2, padding='causal', activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Conv1D(filters=64, kernel_size=2, dilation_rate=4, padding='causal', activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Conv1D(filters=64, kernel_size=2, dilation_rate=8, padding='causal', activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Conv1D(filters=128, kernel_size=1, activation='relu'),
    GlobalAveragePooling1D(),

    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(y_train.shape[1], activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# ===================== TRAIN MODEL =====================
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

start = time.time()
history = model.fit(X_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(X_test, y_test),
                    callbacks=callbacks,
                    verbose=1)
end = time.time()

# ===================== PLOT ACCURACY & LOSS =====================
window = 5 if len(history.history['accuracy']) >= 7 else 3
poly = 2

train_acc = savgol_filter(history.history['accuracy'], window, poly)
val_acc = savgol_filter(history.history['val_accuracy'], window, poly)
train_loss = savgol_filter(history.history['loss'], window, poly)
val_loss = savgol_filter(history.history['val_loss'], window, poly)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label="Train Acc (Smoothed)", color='green')
plt.plot(val_acc, label="Val Acc (Smoothed)", color='blue')
plt.title("Smoothed Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label="Train Loss (Smoothed)", color='red')
plt.plot(val_loss, label="Val Loss (Smoothed)", color='orange')
plt.title("Smoothed Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# ===================== EVALUATION =====================
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=activity_labels.values(),
            yticklabels=activity_labels.values(),
            linewidths=0.5, linecolor='Orange')
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix")
plt.tight_layout(); plt.show()

# Classification Report
print("📊 Classification Report:")
report = classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values(), output_dict=True)
print(classification_report(y_true_labels, y_pred_labels, target_names=activity_labels.values()))

# Sensitivity & Specificity
accuracy = np.mean(y_pred_labels == y_true_labels)
mse = mean_squared_error(y_true_labels, y_pred_labels)
sensitivity = np.mean([report[label]['recall'] for label in activity_labels.values()])

specificity_list = []
for i in range(len(activity_labels)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp_fn = cm.sum() - cm[:, i].sum()
    specificity_list.append(tn / fp_fn if fp_fn != 0 else 0)
specificity = np.mean(specificity_list)

print(f"\n✅ Final Evaluation:")
print(f"✔️ Accuracy     : {accuracy * 100:.2f}%")
print(f"✔️ Sensitivity  : {sensitivity:.4f}")
print(f"✔️ Specificity  : {specificity:.4f}")
print(f"✔️ MSE          : {mse:.4f}")
print(f"✔️ Training Time: {end - start:.2f} sec")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
val_loss = history.history['val_loss'][-1]
val_acc = history.history['val_accuracy'][-1]
print(f"\n🎯 Train Accuracy: {train_acc*100:.2f}% | Loss: {train_loss:.4f}")
print(f"📊 Val Accuracy: {val_acc*100:.2f}%   | Loss: {val_loss:.4f}")
print(f"✅ Test Accuracy: {test_acc*100:.2f}% | Loss: {test_loss:.4f}")

# ===================== ROC CURVE =====================
fpr = dict(); tpr = dict(); roc_auc = dict()
n_classes = y_test.shape[1]
colors = plt.cm.get_cmap('tab10', n_classes).colors

plt.figure(figsize=(6, 5))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f"{activity_labels[i+1]} (AUC = {roc_auc[i]:.2f})",
             color=colors[i % len(colors)])

plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve per Activity Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right", fontsize='small')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 80, 64)         │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 80, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 40, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 40, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 40, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 40, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 40, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 40, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 40, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 40, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 40, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 40, 128)        │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           780 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,140 (219.30 KB)
#  Trainable params: 55,500 (216.80 KB)
#  Non-trainable params: 640 (2.50 KB)
# Epoch 1/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 110ms/step - accuracy: 0.6754 - loss: 1.1605 - val_accuracy: 0.8202 - val_loss: 0.4074 - learning_rate: 0.0010
# Epoch 2/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8238 - loss: 0.3959 - val_accuracy: 0.8769 - val_loss: 0.2779 - learning_rate: 0.0010
# Epoch 3/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - accuracy: 0.8649 - loss: 0.3034 - val_accuracy: 0.8734 - val_loss: 0.2855 - learning_rate: 0.0010
# Epoch 4/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.8763 - loss: 0.2742 - val_accuracy: 0.8784 - val_loss: 0.2804 - learning_rate: 0.0010
# Epoch 5/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 108ms/step - accuracy: 0.8847 - loss: 0.2549 - val_accuracy: 0.8891 - val_loss: 0.2541 - learning_rate: 0.0010
# Epoch 6/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.8927 - loss: 0.2424 - val_accuracy: 0.8965 - val_loss: 0.2327 - learning_rate: 0.0010
# Epoch 7/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.8978 - loss: 0.2330 - val_accuracy: 0.8973 - val_loss: 0.2189 - learning_rate: 0.0010
# Epoch 8/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8948 - loss: 0.2378 - val_accuracy: 0.8975 - val_loss: 0.2331 - learning_rate: 0.0010
# Epoch 9/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 108ms/step - accuracy: 0.9029 - loss: 0.2205 - val_accuracy: 0.9037 - val_loss: 0.2284 - learning_rate: 0.0010
# Epoch 10/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.9053 - loss: 0.2164 - val_accuracy: 0.9030 - val_loss: 0.2147 - learning_rate: 0.0010
# Epoch 11/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9058 - loss: 0.2163 - val_accuracy: 0.9008 - val_loss: 0.2279 - learning_rate: 0.0010
# Epoch 12/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9092 - loss: 0.2097 - val_accuracy: 0.9022 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 13/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - accuracy: 0.9096 - loss: 0.2072 - val_accuracy: 0.8997 - val_loss: 0.2290 - learning_rate: 0.0010
# Epoch 14/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 108ms/step - accuracy: 0.9174 - loss: 0.1942 - val_accuracy: 0.9052 - val_loss: 0.2172 - learning_rate: 5.0000e-04
# Epoch 15/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9185 - loss: 0.1892 - val_accuracy: 0.9122 - val_loss: 0.2050 - learning_rate: 5.0000e-04
# Epoch 16/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9190 - loss: 0.1875 - val_accuracy: 0.9064 - val_loss: 0.2149 - learning_rate: 5.0000e-04
# Epoch 17/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.9189 - loss: 0.1850 - val_accuracy: 0.9042 - val_loss: 0.2233 - learning_rate: 5.0000e-04
# Epoch 18/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.9258 - loss: 0.1773 - val_accuracy: 0.9130 - val_loss: 0.2034 - learning_rate: 5.0000e-04
# Epoch 19/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.9247 - loss: 0.1803 - val_accuracy: 0.9112 - val_loss: 0.2060 - learning_rate: 5.0000e-04
# Epoch 20/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 108ms/step - accuracy: 0.9262 - loss: 0.1770 - val_accuracy: 0.9114 - val_loss: 0.2071 - learning_rate: 5.0000e-04
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 📊 Classification Report:
#                            precision    recall  f1-score   support
#
#            Standing still       0.63      1.00      0.77       151
#      Sitting and relaxing       0.73      1.00      0.85       140
#                Lying down       0.75      1.00      0.86       150
#                   Walking       0.79      1.00      0.88       157
#           Climbing stairs       0.78      0.96      0.86       159
#       Waist bends forward       0.82      0.85      0.84       150
# Frontal elevation of arms       0.68      1.00      0.81       127
# Knees bending (crouching)       0.81      0.99      0.89       149
#                   Cycling       0.76      1.00      0.86       137
#                   Jogging       0.85      1.00      0.92       148
#                   Running       0.86      0.99      0.92       138
#         Jump front & back       0.99      0.89      0.94      4374
#
#                  accuracy                           0.91      5980
#                 macro avg       0.79      0.97      0.87      5980
#              weighted avg       0.93      0.91      0.92      5980
#
#
# ✅ Final Evaluation:
# ✔️ Accuracy     : 91.30%
# ✔️ Sensitivity  : 0.9730
# ✔️ Specificity  : 0.9798
# ✔️ MSE          : 4.8948
# ✔️ Training Time: 431.06 sec
#
# 🎯 Train Accuracy: 92.14% | Loss: 0.1853
# 📊 Val Accuracy: 91.14%   | Loss: 0.2071
# ✅ Test Accuracy: 91.30% | Loss: 0.2034
